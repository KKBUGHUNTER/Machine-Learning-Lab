# %% [markdown]
# # Simple-Linear-Regression
# https://www.kaggle.com/code/devzohaib/simple-linear-regression/notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('tvmarketing.csv')
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
df.shape
# Out:
# (200, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.describe()
# Out:
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
df.isna().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
plt.hist(df['Sales'])
plt.show()

# %%
plt.hist(df['TV'])
plt.show()

# %%
plt.scatter(x=df['TV'], y=df['Sales'])
plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
class SimpleLinearRegration:
    global a0
    global a1
    def fit(leabel,target):
        xy = (target * leabel).sum()
        x_square_sum = (leabel ** 2).sum()

        mean_x = leabel.mean()
        mean_y = target.mean()

        a1 = (len(df) * xy - sum(leabel) * sum(target)) / (len(df) * x_square_sum - (sum(leabel) ** 2))
        a0 = mean_y - a1 * mean_x

    def predict(val):
        return a0 + a1 * val

    def line(test_leabel):
        return a0 + a1 * test_leabel

x = df['TV'][0]
y = df['Sales'][0]
print("val =",x," Result = ", SimpleLinearRegration.predict(x)," Target value = ", y)
x = df['TV'][1]
y = df['Sales'][1]
print("val =",x," Result = ", SimpleLinearRegration.predict(x)," Target value = ", y)
# Out:
# val = 230.1  Result =  17.970774512765537  Target value =  22.1
# val = 44.5  Result =  9.147974048397078  Target value =  10.4

# %%
pos = 49

x = df['TV'][pos]
y = df['Sales'][pos]
print("val =",x," Result = ", SimpleLinearRegration.predict(x)," Target value = ", y)

plt.scatter(df['TV'], df['Sales'], color='blue', label='Data Points')
predicted_TV = SimpleLinearRegration.line(df['TV'])
plt.plot(df['TV'], predicted_TV, color='red', label='Regression Line')
plt.scatter(x, y, color='black', label='Test Data')
plt.xlabel('Sales')
plt.ylabel('TV')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
# Out:
# val = 66.9  Result =  10.21279479409672  Target value =  9.7
